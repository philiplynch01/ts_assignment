# %%
import pandas as pd
import os

# %%
original_metrics = pd.read_csv(os.path.join("..", "og_aeon_summary.csv"))
original_metrics
# Out:
#                 dataset       model  seed  n_train  n_test  series_length  \
# 0                 ACSF1  aeon_hydra    42      100     100           1460
# 1                 Adiac  aeon_hydra    42      390     391            176
# 2    AllGestureWiimoteX  aeon_hydra    42      300     700            500
# 3    AllGestureWiimoteY  aeon_hydra    42      300     700            500
# 4    AllGestureWiimoteZ  aeon_hydra    42      300     700            500
# ..                  ...         ...   ...      ...     ...            ...
# 123                Wine  aeon_hydra    42       57      54            234
# 124        WordSynonyms  aeon_hydra    42      267     638            270
# 125               Worms  aeon_hydra    42      181      77            900
# 126       WormsTwoClass  aeon_hydra    42      181      77            900
# 127                Yoga  aeon_hydra    42      300    3000            426
#
#      n_classes  total_time  peak_memory_mb  accuracy  f1_macro  f1_weighted  \
# ...

# %%
optimised_metrics = pd.read_csv(os.path.join("..", "optimised_aeon_summary.csv"))
optimised_metrics
# Out:
#                 dataset       model  seed  n_train  n_test  series_length  \
# 0                 ACSF1  aeon_hydra    42      100     100           1460
# 1                 Adiac  aeon_hydra    42      390     391            176
# 2    AllGestureWiimoteX  aeon_hydra    42      300     700            500
# 3    AllGestureWiimoteY  aeon_hydra    42      300     700            500
# 4    AllGestureWiimoteZ  aeon_hydra    42      300     700            500
# ..                  ...         ...   ...      ...     ...            ...
# 123                Wine  aeon_hydra    42       57      54            234
# 124        WordSynonyms  aeon_hydra    42      267     638            270
# 125               Worms  aeon_hydra    42      181      77            900
# 126       WormsTwoClass  aeon_hydra    42      181      77            900
# 127                Yoga  aeon_hydra    42      300    3000            426
#
#      n_classes  total_time  peak_memory_mb  accuracy  f1_macro  f1_weighted  \
# ...

# %%
original_metrics[["total_time", "accuracy"]].describe()
# Out:
#        total_time    accuracy
# count  128.000000  128.000000
# mean     9.411633    0.848360
# std     38.763925    0.149701
# min      0.039449    0.324367
# 25%      0.599594    0.766558
# 50%      1.632669    0.892356
# 75%      6.777848    0.969003
# max    432.228235    1.000000

# %%
optimised_metrics[["total_time", "accuracy"]].describe()
# Out:
#        total_time    accuracy
# count  128.000000  128.000000
# mean     3.124716    0.848006
# std      4.764253    0.150081
# min      0.037085    0.324367
# 25%      0.429451    0.766558
# 50%      1.026530    0.892356
# 75%      3.517861    0.968619
# max     30.928476    1.000000
